-- %%
use catalog hive_metastore;
drop table order;
create table orders as select * from parquet.`dbfs:/mnt/demo-datasets/bookstore/orders`

-- %%
select count(*) from orders

-- %%
select * from orders limit 10;

-- %%
describe extended orders

-- %%
%fs ls 'dbfs:/user/hive/warehouse/orders'

-- %%
%fs ls 'dbfs:/mnt/demo-datasets/bookstore/orders'

-- %%
select count(*) from delta.`dbfs:/user/hive/warehouse/orders/`

-- %%
select count(*) from parquet.`dbfs:/mnt/demo-datasets/bookstore/orders/`

-- %%
%python
dbutils.fs.cp("dbfs:/mnt/demo-datasets/bookstore/orders/export_001.parquet","dbfs:/mnt/demo-datasets/bookstore/orders/export_006.parquet")

-- %%
%fs ls "dbfs:/mnt/demo-datasets/bookstore/orders"

-- %%
select count(*) from parquet.`dbfs:/mnt/demo-datasets/bookstore/orders`

-- %%
select count(*) from delta.`dbfs:/user/hive/warehouse/orders`

-- %%
%python
dbutils.fs.cp("dbfs:/mnt/demo-datasets/bookstore/orders/export_006.parquet","dbfs:/user/hive/warehouse/orders/export_006.parquet")

-- %%
select count(*) from delta.`dbfs:/user/hive/warehouse/orders`

-- %%
select count(*) from orders

-- %%
refresh table orders

-- %%
select count(*) from orders

-- %%
select count(*) from parquet.`dbfs:/mnt/demo-datasets/bookstore/orders/`

-- %%
copy into orders
from "dbfs:/mnt/demo-datasets/bookstore/orders/"
FILEFORMAT = parquet;

-- %%
select count(*) from orders

-- %%
describe history orders

-- %%
drop table if exists orders;
create or replace table orders as select * from parquet.`dbfs:/mnt/demo-datasets/bookstore/orders`;
select count(*) from orders;

-- %%
select count(*) from parquet.`dbfs:/mnt/demo-datasets/bookstore/orders`;

-- %%
%fs ls "dbfs:/user/hive/warehouse/orders"

-- %%
copy into orders from "dbfs:/mnt/demo-datasets/bookstore/orders" fileformat = parquet

-- %%
%fs ls "dbfs:/user/hive/warehouse/orders"

-- %% [markdown]
-- ## Overwriting Tables

-- %%
drop table order;
create or replace table orders
as select * from parquet.`dbfs:/mnt/demo-datasets/bookstore/orders`;

-- %%
DESCRIBE HISTORY orders

-- %%
select count(*) from orders;

-- %%
insert overwrite orders
select * from parquet.`dbfs:/mnt/demo-datasets/bookstore/orders`

-- %%
select count(*) from orders

-- %%
DESCRIBE HISTORY orders

-- %%
insert overwrite orders
select *, current_timestamp() from parquet.`dbfs:/mnt/demo-datasets/bookstore/orders`

-- %% [markdown]
-- ## Appending Data

-- %%
insert into orders select *, current_timestamp() from parquet.`dbfs:/mnt/demo-datasets/bookstore/orders`;

-- %%
select count(*) from parquet.`dbfs:/mnt/demo-datasets/bookstore/orders-new`;

-- %%
insert into orders select * from parquet.`dbfs:/mnt/demo-datasets/bookstore/orders-new`;

-- %%
select count(*) from orders

-- %%
copy into orders from "dbfs:/mnt/demo-datasets/bookstore/orders-new" fileformat = parquet

-- %%
select count(*) from orders;

-- %% [markdown]
-- ## Merging Data

-- %%
create or replace temp view customers_updates as 
select * from json.`dbfs:/mnt/demo-datasets/bookstore/customers-json-new`;


select *, count(*) over() as total from customers_updates limit 5;

-- %%
select *, count(*) over() as total from customers limit 5

-- %%
merge into customers c
using customers_updates u
on c.customer_id = u.customer_id
when matched and c.email is null and u.email is not null then
  update set c.email = u.email, c.updated = u.updated
when not matched then 
  insert *;

-- %%
select count(*) from customers;

-- %%
CREATE OR REPLACE TEMP VIEW books_updates
USING CSV
OPTIONS (
  path = "dbfs:/mnt/demo-datasets/bookstore/books-csv-new",
  header = "true",
  delimiter = ";"
);

select *, count(*) over() as total from books_updates limit 5;

-- %%
describe extended books_updates

-- %%
CREATE OR REPLACE TEMP VIEW books_updates
   (book_id STRING, title STRING, author STRING, category STRING, price DOUBLE)
USING CSV
OPTIONS (
  path = "dbfs:/mnt/demo-datasets/bookstore/books-csv-new",
  header = "true",
  delimiter = ";"
);

select *, count(*) over() as total from books_updates limit 5;
