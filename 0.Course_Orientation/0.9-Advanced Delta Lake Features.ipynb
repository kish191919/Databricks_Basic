-- %% [markdown]
-- ## Delta Time Travel

-- %%
USE CATALOG hive_metastore

-- %%
DESCRIBE HISTORY employees

-- %%
select * from employees

-- %%
select * from employees version as of 1

-- %%
select * from employees@v1

-- %%
select * from employees TIMESTAMP as of '2026-01-12T04:22:12.000+00:00'

-- %%
DELETE FROM employees

-- %%
SELECT * FROM employees

-- %%
RESTORE TABLE employees TO VERSION AS OF 1

-- %%
SELECT * FROM employees

-- %%
DESCRIBE HISTORY employees

-- %% [markdown]
-- ## OPTIMIZE Command

-- %%
DESCRIBE DETAIL employees

-- %%
Insert into employees
values 
  (10, "Adam", 3500.0),
  (20, "Sarah", 4020.5);

INSERT INTO employees
VALUES
  (30, "John", 2999.3),
  (40, "Thomas", 4000.3);

INSERT INTO employees
VALUES
  (50, "Anna", 2500.0);

INSERT INTO employees
VALUES
  (60, "Kim", 6200.3)

-- %%
DESCRIBE DETAIL employees

-- %%
OPTIMIZE employees
ZORDER BY id

-- %%
DESCRIBE DETAIL employees

-- %%
DESCRIBE HISTORY employees

-- %%
%fs ls 'dbfs:/user/hive/warehouse/employees'

-- %% [markdown]
-- ## VACUUM Command

-- %%
vacuum employees

-- %%
%fs ls 'dbfs:/user/hive/warehouse/employees'

-- %%
SET spark.databricks.delta.retentionDurationCheck.enabled;

-- %%
SET spark.databricks.delta.retentionDurationCheck.enabled = false;

-- %%
VACUUM employees RETAIN 0 HOURS

-- %%
%fs ls 'dbfs:/user/hive/warehouse/employees'

-- %%
DESCRIBE HISTORY employees

-- %%
select 604800000/ (1000*60*60*24) as Day

-- %%
VACUUM employees

-- %%
DESCRIBE HISTORY employees

-- %% [markdown]
-- ## Dropping Tables

-- %%
drop table employees

-- %%
select * from employees

-- %%
%fs ls 'dbfs:/user/hive/warehouse/employees'
