-- %%
%sql
CREATE TABLE books (
  id INT,
  title STRING,
  price DOUBLE
)
USING DELTA;

-- %%
describe detail books

-- %%
%python
dbutils.fs.ls("/")

-- %% [markdown]
-- | 경로                     | 성격            | 용도                   | 실무 사용     |
-- | ---------------------- | ------------- | -------------------- | --------- |
-- | `/databricks-datasets` | Read-only     | Databricks 제공 샘플 데이터 | 🔹 학습     |
-- | `/Shared`              | 공유            | 사용자 간 공유 파일          | 🔹 가벼운 공유 |
-- | `/user`                | 개인            | 사용자 홈 디렉터리           | 🔹 개인 작업  |
-- | `/databricks-results`  | 시스템           | 쿼리 결과 저장             | ❌ 직접 사용 X |
-- | `/local_disk0`         | 로컬 디스크        | 클러스터 노드 로컬 저장소       | ⚠️ 임시     |
-- | `/mnt`                 | 마운트           | 외부 스토리지 마운트          | 🔸 (구방식)  |
-- | `/Volumes`             | Unity Catalog | UC Volume 경로         | ⭐⭐⭐ 표준    |
-- | `/Volume`, `/volume`   | UI 잔재         | 내부/호환용               | ❌ 무시      |

-- %%
%python
dbutils.fs.ls('/user/hive/warehouse')

-- %%
CREATE CATALOG demo_catalog;

-- %%
%python
dbutils.fs.ls('/user/hive/warehouse/default')

-- %%
DESCRIBE EXTENDED books;
