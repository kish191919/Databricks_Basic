# %%
print("Hello World")

# %%
# %sql
SELECT 'Hello World'

# %% [markdown]
# # Title 1
# ## Title 2
# ### Title 3
#
#
# text with **Bold** and *italicized*
#
# Ordered list
# 1. first
# 2. second
# 3. third
#
# 1. first
# 1. second
# 1. third
#
#
# Unordered list
# * Coffee
# * Bread
# * Milk
#
# Images:
# ![Associate-Badge](https://www.databricks.com/wp-content/uploads/2022/04/associate-badge-eng.svg)
#
#
# Tables:
# | user_id | user_name|
# |---------|----------|
# |     1   |  Danny   |
# |     2   |  Nancy   |
# |     3   |  James   |
#
#
# Links : <a href="https://docs.databricks.com/notebooks/notebooks-manage.html" target="_blank">  Manage notebooks </a>

# %%
# %run ./Databricks_another_notebook

# %%
print(Greeting)

# %%
# %fs ls '/'

# %%
# %fs ls 'dbfs:/databricks-datasets/'

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
Files = dbutils.fs.ls("dbfs:/databricks-datasets/")
display(Files)
